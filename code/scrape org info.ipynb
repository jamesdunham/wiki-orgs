# %% [markdown]
# ## Scrape Wikipedia

# %%
#! /usr/bin/env python3
# -*- coding: utf-8 -*-
# vim:fenc=utf-8

"""

"""

import wikipedia
from lxml import html, etree
import pandas as pd
import pandas.io.sql as pd_sql
import numpy as np
import sqlite3
import re

wikipedia.set_rate_limiting(True)

def find_page(org_row):
    hits = wikipedia.search(org_row['name'], results=1)
    try:
        page = wikipedia.page(hits[0])
    except wikipedia.exceptions.DisambiguationError:
        return('DisambiguationError')
    except wikipedia.exceptions.PageError:
        return('PageError')
    except:
        return('Error')
    return(page)

def add_page(org_row):
    if 'page' in org_row:
        print('Skipping {}'.format(org_row['name']))
        return(org_row['page'])
    else:
        print('Looking for {}'.format(org_row['name']))
        page = find_page(org_row)
        return(page)
    
def get_infobox(series):
    try:
        df = pd.read_html(series['page'].html(), attrs = {'class': 'infobox vcard'})[0]
        df.columns = ['key', 'value']
        df = df.set_index('key')
        return(df)
    except:
        return(None)

    
def get_row_attr(row, attr):
    try:
        return(getattr(row['page'], attr))
    except (KeyError, AttributeError):
        return(None)

# %%
orgs = pd.read_csv('~/projects/group-positions/position_counts.csv')
orgs = orgs.sort_values('count', ascending = False)
orgs = orgs.drop_duplicates('name')
orgs.head()
# orgs = orgs[1:10]
# Out:
#                                      name  count    topcode
# 0                U.S. Chamber of Commerce    625      Other
# 3   National Association of Manufacturers    380      Other
# 8                                 AFL-CIO    361      Other
# 10         National Education Association    359  Education
# 12                         Public Citizen    242      Other

# %%
orgs['page'] = orgs.apply(add_page, axis=1)
# Out:
# Looking for U.S. Chamber of Commerce
# Looking for National Association of Manufacturers
# Looking for AFL-CIO
# Looking for National Education Association
# Looking for Public Citizen
# Looking for National Taxpayers Union
# Looking for Sierra Club
# Looking for American Federation of State, County and Municipal Employees
# Looking for American Civil Liberties Union
# Looking for Americans for Tax Reform
# Looking for Natural Resources Defense Council
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385             try:  # Python 2.7, use buffering of HTTP responses
# --> 386                 httplib_response = conn.getresponse(buffering=True)
#     387             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-e11b04b8ee4c> in <module>()
# ----> 1 orgs['page'] = orgs.apply(add_page, axis=1)
#
# /usr/local/lib/python3.5/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4059                     if reduce is None:
#    4060                         reduce = True
# -> 4061                     return self._apply_standard(f, axis, reduce=reduce)
#    4062             else:
#    4063                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python3.5/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4115                     labels = self._get_agg_axis(axis)
#    4116                     result = lib.reduce(values, func, axis=axis, dummy=dummy,
# -> 4117                                         labels=labels)
#    4118                     return Series(result, index=labels)
#    4119                 except Exception:
#
# pandas/src/reduce.pyx in pandas.lib.reduce (pandas/lib.c:43539)()
#
# pandas/src/reduce.pyx in pandas.lib.Reducer.get_result (pandas/lib.c:33736)()
#
# <ipython-input-27-2669603c3ae3> in add_page(org_row)
#      35     else:
#      36         print('Looking for {}'.format(org_row['name']))
# ---> 37         page = find_page(org_row)
#      38         return(page)
#      39
#
# <ipython-input-27-2669603c3ae3> in find_page(org_row)
#      18
#      19 def find_page(org_row):
# ---> 20     hits = wikipedia.search(org_row['name'], results=1)
#      21     try:
#      22         page = wikipedia.page(hits[0])
#
# /usr/local/lib/python3.5/site-packages/wikipedia/util.py in __call__(self, *args, **kwargs)
#      26       ret = self._cache[key]
#      27     else:
# ---> 28       ret = self._cache[key] = self.fn(*args, **kwargs)
#      29
#      30     return ret
#
# /usr/local/lib/python3.5/site-packages/wikipedia/wikipedia.py in search(query, results, suggestion)
#     101     search_params['srinfo'] = 'suggestion'
#     102
# --> 103   raw_results = _wiki_request(search_params)
#     104
#     105   if 'error' in raw_results:
#
# /usr/local/lib/python3.5/site-packages/wikipedia/wikipedia.py in _wiki_request(params)
#     735     time.sleep(int(wait_time.total_seconds()))
#     736
# --> 737   r = requests.get(API_URL, params=params, headers=headers)
#     738
#     739   if RATE_LIMIT:
#
# /usr/local/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /usr/local/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /usr/local/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# /usr/local/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     615
#     616         # Resolve redirects if allowed.
# --> 617         history = [resp for resp in gen] if allow_redirects else []
#     618
#     619         # Shuffle things around if there's history.
#
# /usr/local/lib/python3.5/site-packages/requests/sessions.py in <listcomp>(.0)
#     615
#     616         # Resolve redirects if allowed.
# --> 617         history = [resp for resp in gen] if allow_redirects else []
#     618
#     619         # Shuffle things around if there's history.
#
# /usr/local/lib/python3.5/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, **adapter_kwargs)
#     175                 proxies=proxies,
#     176                 allow_redirects=False,
# --> 177                 **adapter_kwargs
#     178             )
#     179
#
# /usr/local/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     594
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#     598         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /usr/local/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   timeout=timeout_obj,
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#     597             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     387             except TypeError:  # Python 2.6 and older, Python 3
#     388                 try:
# --> 389                     httplib_response = conn.getresponse()
#     390                 except Exception as e:
#     391                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/local/Cellar/python3/3.5.2_1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# /usr/local/Cellar/python3/3.5.2_1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/local/Cellar/python3/3.5.2_1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/local/Cellar/python3/3.5.2_1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# /usr/local/Cellar/python3/3.5.2_1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/ssl.py in recv_into(self, buffer, nbytes, flags)
#     927                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     928                   self.__class__)
# --> 929             return self.read(nbytes, buffer)
#     930         else:
#     931             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/local/Cellar/python3/3.5.2_1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/ssl.py in read(self, len, buffer)
#     789             raise ValueError("Read on closed or unwrapped SSL socket.")
#     790         try:
# --> 791             return self._sslobj.read(len, buffer)
#     792         except SSLError as x:
#     793             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/local/Cellar/python3/3.5.2_1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/ssl.py in read(self, len, buffer)
#     573         """
#     574         if buffer is not None:
# --> 575             v = self._sslobj.read(len, buffer)
#     576         else:
#     577             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
orgs = orgs.set_index(orgs.name)
orgs.head()
orgs.tail()
orgs.page.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-39c97d9a933d> in <module>()
#       2 orgs.head()
#       3 orgs.tail()
# ----> 4 orgs.page.head()
#
# /usr/local/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'page'

# %%
orgs['url'] = orgs.apply(lambda row: get_row_attr(row, 'url'), axis=1)
orgs['summary'] = orgs.apply(lambda row: get_row_attr(row, 'summary'), axis=1)

# %%
orgs['links'] = orgs.apply(lambda row: get_row_attr(row, 'links'), axis=1)
orgs['references'] = orgs.apply(lambda row: get_row_attr(row, 'references'), axis=1)

# %% [markdown]
# ## Explore

# %%
#orgs.to_pickle('orgs.pkl')
orgs = pd.read_pickle('orgs.pkl')

# %%
orgs.tail()
# Out:
#                                                                                                  name  \
# name
# American Council on the Teaching of Foreign Lan...  American Council on the Teaching of Foreign La...
# Parents for Public Schools                                                 Parents for Public Schools
# National Institute on Out-of-School Time                     National Institute on Out-of-School Time
# Los Angeles Education Partnership                                   Los Angeles Education Partnership
# Zonta International                                                               Zonta International
#
#                                                     count         topcode  \
# name
# American Council on the Teaching of Foreign Lan...      1       Education
# Parents for Public Schools                              1       Education
# National Institute on Out-of-School Time                1       Education
# Los Angeles Education Partnership                       1       Education
# Zonta International                                     1  Women's Issues
#
#                                                                                                  page  \
# name
# American Council on the Teaching of Foreign Lan...  <WikipediaPage 'American Council on the Teachi...
# Parents for Public Schools                                              <WikipediaPage 'Dick Molpus'>
# National Institute on Out-of-School Time                      <WikipediaPage 'After-school activity'>
# Los Angeles Education Partnership                   <WikipediaPage 'East Los Angeles Renaissance A...
# Zonta International                                             <WikipediaPage 'Zonta International'>
#
#                                                                                                   url  \
# name
# American Council on the Teaching of Foreign Lan...  https://en.wikipedia.org/wiki/American_Council...
# Parents for Public Schools                                  https://en.wikipedia.org/wiki/Dick_Molpus
# National Institute on Out-of-School Time            https://en.wikipedia.org/wiki/After-school_act...
# Los Angeles Education Partnership                   https://en.wikipedia.org/wiki/East_Los_Angeles...
# Zonta International                                 https://en.wikipedia.org/wiki/Zonta_International
#
#                                                                                               summary
# name
# American Council on the Teaching of Foreign Lan...  The American Council on the Teaching of Foreig...
# Parents for Public Schools                          Richard "Dick" Molpus (born September 7, 1949)...
# National Institute on Out-of-School Time            An after-school activity is any organized prog...
# Los Angeles Education Partnership                   The East Los Angeles Renaissance Academy, offi...
# Zonta International                                 Zonta International is an international servic...

# %%
infoboxes = {}
for key, row in o.iterrows():
    infobox = get_infobox(row)
    infoboxes[key] = infobox
infoboxes = pd.concat(infoboxes)
infoboxes = infoboxes.dropna()
infoboxes.index.names = ['name', 'field']
infoboxes.head()
# Out:
#                                                    value
# name field
# AARP Motto                         "Real Possibilities."
#      Predecessor   National Retired Teachers Association
#      Formation                               1958 (1958)
#      Tax ID no.                            95-1985500[1]
#      Headquarters                 Washington, D.C., U.S.

# %%
# Sample the result for a glimpse
infoboxes.ix[np.random.choice(infoboxes.index.get_level_values(0), 2)]
# Out:
#                                                                                value
# name      field
# Microsoft Type                                                                Public
#           Traded as                NASDAQ: MSFTDow Jones Industrial Average Compo...
#           Industry                 Computer softwareComputer hardwareConsumer ele...
#           Founded                  April 4, 1975; 41 years ago (1975-04-04)Albuqu...
#           Founders                                              Bill GatesPaul Allen
#           Headquarters             Microsoft Redmond campus, Redmond, Washington,...
#           Area served                                                      Worldwide
#           Key people               John W. Thompson (Chairman) Satya Nadella (CEO...
#           Products                 Windows  Office  Servers  Skype  Visual Studio...
#           Services                 MSN  Bing  OneDrive  MSDN  Outlook.com  TechNe...
#           Revenue                                         US$85.32 billion (2016)[2]
#           Operating income                                US$19.86 billion (2016)[2]
#           Net income                                      US$16.79 billion (2016)[2]
#           Total assets                                   US$193.69 billion (2016)[2]
#           Total equity                                    US$71.99 billion (2016)[2]
#           Owner                                                   Bill Gates (3%)[3]
#           Number of employees                             114,000 (June 30, 2016)[4]
#           Subsidiaries                                List of Microsoft subsidiaries
#           Website                                                  www.microsoft.com
# AARP      Motto                                                "Real Possibilities."
#           Predecessor                          National Retired Teachers Association
#           Formation                                                      1958 (1958)
#           Tax ID no.                                                   95-1985500[1]
#           Headquarters                                        Washington, D.C., U.S.
#           Membership                                                     37,000,000+
#           Chief Executive Officer                                  Jo Ann Jenkins[1]
#           President                                              Jeannine English[1]
#           Board Chair                                               Carol Raphael[1]
#           Subsidiaries             AARP Foundation;AARP Institute;Legal Counsel f...
#           Revenue (2014)                                           $1,486,310,000[2]
#           Expenses (2014)                                          $1,468,824,000[2]
#           Staff                                                             1,986[1]
#           Volunteers                                                       17,499[1]
#           Website                                                           aarp.org
#           Formerly called                    American Association of Retired Persons

# %%
# Which orgs had no Wikipedia pag?
no_wiki = set(orgs['name']) - set(infoboxes.index.get_level_values(0).unique())

# Which have the wrong page?
# Difficult to say without manual review 

# Which of the pages gave location info? 
fields = infoboxes.index.levels[1]
loc_fields = fields[fields.str.contains('address|location|headquarters|office(?!r)|coordinates', flags=re.I)]
infoboxes.unstack().loc[slice(str(loc_fields))].index.values
# Out:
# array(['AARP', 'AFL-CIO', 'American Academy of Pediatrics',
#        'American Bankers Association', 'American Bar Association',
#        'American Civil Liberties Union',
#        'American Council of Engineering Companies',
#        'American Farm Bureau Federation',
#        'American Federation of Government Employees',
#        'American Federation of State, County and Municipal Employees',
#        'American Federation of Teachers',
#        'American Hotel & Lodging Association',
#        'American Immigration Lawyers Association', 'American Legion',
#        'American Library Association', 'American Medical Association',
#        'American Petroleum Institute',
#        'American Public Health Association',
#        'Americans for Financial Reform', 'Americans for Prosperity',
#        'Americans for Tax Reform', 'Associated Builders & Contractors',
#        'Center for American Progress', 'Common Cause',
#        'Communications Workers of America',
#        'Competitive Enterprise Institute', 'Consumer Action',
#        'Consumers Union', 'Council for Citizens Against Government Waste',
#        'Defenders of Wildlife', 'Earthjustice', 'Environment America',
#        'FreedomWorks', 'Friends Committee on National Legislation',
#        'Friends of the Earth', 'Heritage Foundation',
#        'Human Rights Campaign', 'Humane Society of the United States'], dtype=object)

# %%
# Which didn't?

# %%
#infoboxes.to_pickle('infoboxes.pkl')
infoboxes = pd.read_pickle('../data/infoboxes.pkl')

# %%
infoboxes
# Out:
#                                                                                                                         value
# name                                               key
# AARP                                               Motto                                                "Real Possibilities."
#                                                    Predecessor                          National Retired Teachers Association
#                                                    Formation                                                      1958 (1958)
#                                                    Tax ID no.                                                   95-1985500[1]
#                                                    Headquarters                                        Washington, D.C., U.S.
#                                                    Membership                                                     37,000,000+
#                                                    Chief Executive Officer                                  Jo Ann Jenkins[1]
#                                                    President                                              Jeannine English[1]
#                                                    Board Chair                                               Carol Raphael[1]
#                                                    Subsidiaries             AARP Foundation;AARP Institute;Legal Counsel f...
#                                                    Revenue (2014)                                           $1,486,310,000[2]
#                                                    Expenses (2014)                                          $1,468,824,000[2]
#                                                    Staff                                                             1,986[1]
#                                                    Volunteers                                                       17,499[1]
#                                                    Website                                                           aarp.org
#                                                    Formerly called                    American Association of Retired Persons
# AFL-CIO                                            Full name                American Federation of Labor and Congress of I...
#                                                    Founded                        December 4, 1955; 60 years ago (1955-12-04)
#                                                    Members                                               12,741,859 (2014)[1]
#                                                    Affiliation                                                           ITUC
#                                                    Key people                                    Richard Trumka, president[2]
#                                                    Office location                                           Washington, D.C.
#                                                    Country                                                      United States
#                                                    Website                                                         aflcio.org
# American Academy of Pediatrics                     Motto                              Dedicated to the health of all children
#                                                    Formation                                        1930; 86 years ago (1930)
#                                                    Type                                              Professional association
#                                                    Headquarters                    Elk Grove Village, Illinois, United States
#                                                    Coordinates              42°02′12″N 87°58′58″W﻿ / ﻿42.0366°N 87.9827°W﻿...
#                                                    Membership                                                           64000
# ...                                                                                                                       ...
# U.S. PIRG                                          Motto                                    Standing up to powerful interests
#                                                    Formation                                                             1971
#                                                    Founder                                                     Ralph Nader[1]
#                                                    Type                                                 Advocacy organization
#                                                    Website                                                         uspirg.org
# Union of Concerned Scientists                      Motto                         Science for a healthy planet and safer world
#                                                    Formation                                                             1969
#                                                    Headquarters                                  Cambridge, Massachusetts, US
#                                                    Membership                                                    over 200,000
#                                                    Exec. Dir.                                                   Kathleen Rest
#                                                    President                                                  Kenneth Kimmell
#                                                    Founder                                                     Kurt Gottfried
#                                                    Website                                                         ucsusa.org
# United Food and Commercial Workers Internationa... Full name                               United Food and Commercial Workers
#                                                    Founded                                                June 1979 (1979-06)
#                                                    Members                                                1,274,156 (2013)[1]
#                                                    Affiliation                                                   AFL-CIO, CLC
#                                                    Key people               Anthony "Marc" Perrone, International Presiden...
#                                                    Office location                                           Washington, D.C.
#                                                    Country                                              United States, Canada
#                                                    Website                                                       www.ufcw.org
# United Steelworkers                                Full name                                              United Steelworkers
#                                                    Founded                                          May 22, 1942 (1942-05-22)
#                                                    Members                                                  860,294 (2015)[1]
#                                                    Head union                                                 Workers Uniting
#                                                    Affiliation                                                   AFL-CIO, CLC
#                                                    Key people                                           Leo Gerard, president
#                                                    Office location                                   Pittsburgh, Pennsylvania
#                                                    Country                                              United States, Canada
#                                                    Website                                                        www.usw.org
#
# [609 rows x 1 columns]

# %%
infoboxes.to_csv('../data/infoboxes.csv')
